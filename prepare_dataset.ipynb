# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoAnn/Legal_Document_IR/blob/main/prepare_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load dataset json

# %%
import gdown
import pandas as pd

# %%
name = 'pidana_1100.json'
gdown.download(f'https://drive.google.com/file/d/1_vl9pXOpblb98VP2XWujhzn-wrZpzmZq/view?usp=sharing', name, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_vl9pXOpblb98VP2XWujhzn-wrZpzmZq
# To: /content/pidana_1100.json
# 100%|██████████| 94.5M/94.5M [00:00<00:00, 106MB/s]
# 'pidana_1100.json'

# %%
#annotated dataset putusan pidana scraped from https://putusan3.mahkamahagung.go.id/
df = pd.read_json('pidana_1100.json')
df
# Out:
#                                                    text  \
# 0     [PUTUSAN, ., NOMOR, :, 1974, /, Pid, ., Sus, /...
# 1     [PUTUSAN, Nomor, 1368, /, Pid, ., B, /, 2018, ...
# 2     [PUTUSAN, Nomor, 985, /, Pid, ., Sus, /, 2017,...
# 3     [PUTUSAN, No, ., 924, /, Pid, ., B, /, 2014, /...
# 4     [PUTUSAN, Nomor, 68, /, Pid, ., B, /, 2016, /,...
# ...                                                 ...
# 1095  [1, putusan, no, ., 21, /, pid, ., b, /, 2012,...
# 1096  [dir1ektori, putusan, mahkamah, agung, republi...
# 1097  [putusan, nomor, :, 376, /, pid, ., b, /, 2012...
# 1098  [putusan, nomor, :, 79, /, pid, ., sus, /, 201...
# 1099  [putusan, nomor, :, 121, /, pid, ., b, /, 2010...
#
#                                               text-tags
# 0     [O, O, O, O, B_VERN, I_VERN, I_VERN, I_VERN, I...
# 1     [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 2     [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 3     [O, O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VE...
# 4     [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# ...                                                 ...
# 1095  [O, O, O, O, B_VERN, I_VERN, I_VERN, I_VERN, I...
# 1096  [O, O, O, O, O, O, O, O, O, B_VERN, I_VERN, I_...
# 1097  [O, O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VE...
# 1098  [O, O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VE...
# 1099  [O, O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VE...
#
# [1100 rows x 2 columns]

# %% [markdown]
# #Formatting

# %%
#fill empty/none value with ' ' for text, and 'O' for tags
df['text'] = df.apply(lambda row: [x if x is not None else ' ' for x in row['text']], axis=1)
df['text-tags'] = df.apply(lambda row: [x if x is not None else 'O' for x in row['text-tags']], axis=1)

# %%
new_df= pd.DataFrame([])

# %%
new_df['text'] = df["text"].apply(lambda x: " ".join(x))
new_df['labels'] = df["text-tags"].apply(lambda x: " ".join(x))
new_df
# Out:
#                                                    text  \
# 0     PUTUSAN . NOMOR : 1974 / Pid . Sus / 2012 / PN...
# 1     PUTUSAN Nomor 1368 / Pid . B / 2018 / PN Jkt ....
# 2     PUTUSAN Nomor 985 / Pid . Sus / 2017 / PN JKT ...
# 3     PUTUSAN No . 924 / Pid . B / 2014 / PN . Jkt ....
# 4     PUTUSAN Nomor 68 / Pid . B / 2016 / PN . JKT ....
# ...                                                 ...
# 1095  1 putusan no . 21 / pid . b / 2012 / pn . tmg ...
# 1096  dir1ektori putusan mahkamah agung republik ind...
# 1097  putusan nomor : 376 / pid . b / 2012 / pn . kd...
# 1098  putusan nomor : 79 / pid . sus / 2015 / pn . b...
# 1099  putusan nomor : 121 / pid . b / 2010 / pn . sm...
#
#                                                  labels
# 0     O O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_V...
# 1     O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VERN ...
# 2     O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VERN ...
# 3     O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VER...
# 4     O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VERN ...
# ...                                                 ...
# 1095  O O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_V...
# 1096  O O O O O O O O O B_VERN I_VERN I_VERN I_VERN ...
# 1097  O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VER...
# 1098  O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VER...
# 1099  O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_VER...
#
# [1100 rows x 2 columns]

# %% [markdown]
# #save to csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
test_df = new_df["text"]
test_df.to_csv("/content/drive/MyDrive/Legal_IR/pidana_1100_textonly.csv")
