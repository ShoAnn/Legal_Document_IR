# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoAnn/Legal_Document_IR/blob/main/TFIDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, glob, re, sys, random, unicodedata, collections
import zipfile
import pandas as pd
import numpy as np
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer

from tqdm import tqdm
from functools import reduce
from collections import Counter


STOP_WORDS = set(stopwords.words('indonesian'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def read_and_combine_xml_from_zip(zip_file_path, n):
    """
    Reads the first n XML files from a ZIP file, concatenates them into a single DataFrame,
    and returns the combined DataFrame.

    Args:
        zip_file_path (str): The path to the ZIP file.

    Returns:
        pd.DataFrame: The combined DataFrame from the parsed XML files.
    """

    data = []
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        file_count = 0
        for filename in zip_ref.namelist():
            if filename.endswith('.xml'):
                try:
                    with zip_ref.open(filename) as xml_file:
                        # Use the appropriate XPath expression based on your needs
                        rows = pd.read_xml(xml_file, xpath='//putusan')  # Example: Read all "putusan" elements
                        data.append(rows)
                        file_count += 1
                        if file_count >= n:
                            break
                except Exception as e:
                    print(f"Error parsing XML file '{filename}': {e}")

    # Concatenate DataFrames into a single DataFrame
    combined_df = pd.concat(data, ignore_index=True)
    return combined_df

# %%
zip_file_path = '/content/drive/MyDrive/Legal_IR/Dataset/indo-law-main.zip'  # Replace with your ZIP file path
df = read_and_combine_xml_from_zip(zip_file_path, 1001)

# %%
df
# Out:
#         amar                                       amar_lainnya  \
# 0     pidana                                              hukum
# 1     pidana                                              hukum
# 2     pidana  jatuh-pidana-oleh-karena-itu-kepada-dakwa-ir-b...
# 3     pidana                                              hukum
# 4     pidana                                              hukum
# ...      ...                                                ...
# 996   pidana  pidana-penjara-lama-4-empat-tahun-dan-8-delapa...
# 997   pidana                         pidana-penjara-waktu-tentu
# 998   pidana                                              hukum
# 999   pidana                                              hukum
# 1000  pidana                                              hukum
#
#                                     id    klasifikasi  lama_hukuman  \
# 0     00035681c8d944203f25d2e8215ae2bf    pidana-umum           210
# 1     000399ce26773e18695ce14f519cb9e6    pidana-umum           720
# 2     0006582ad67cd9bd1ddf4261a09bf382    pidana-umum           120
# 3     00092bbac1a705aa44f2e10a0511cc0c  pidana-khusus          3240
# 4     0009b7fa2e45129b1755ddbdf35c7eec  pidana-khusus           300
# ...                                ...            ...           ...
# 996   0a884bfac05948c4e5fa8d041a7554de  pidana-khusus          1680
# 997   0a8e59c1433760de863bf79d59803762    pidana-umum          1080
# 998   0a929fce67a32e241f501b9887c66b98    pidana-umum          2880
# 999   0a9abd811f8abb37459348f38c8fc4ec  pidana-khusus          1440
# 1000  0a9c862be8efe0c64a7fcbe8e38c81a2  pidana-khusus          1800
#
#      lembaga_peradilan provinsi                   status  \
# 0             pn-kudus   jateng  berkekuatan-hukum-tetap
# 1             pn-demak   jateng  berkekuatan-hukum-tetap
# 2            pn-kediri    jatim  berkekuatan-hukum-tetap
# 3            pn-klaten   jateng  berkekuatan-hukum-tetap
# 4             pn-blora   jateng  berkekuatan-hukum-tetap
# ...                ...      ...                      ...
# 996      pn-yogyakarta    yogya  berkekuatan-hukum-tetap
# 997       pn-bangkalan    jatim  berkekuatan-hukum-tetap
# 998       pn-bangkalan    jatim  berkekuatan-hukum-tetap
# 999    pn-bale-bandung    jabar  berkekuatan-hukum-tetap
# 1000        pn-bandung    jabar  berkekuatan-hukum-tetap
#
#                          sub_klasifikasi  \
# 0                              pemalsuan
# 1                              pencurian
# 2     kejahatan-terhadap-keamanan-negara
# 3                                   anak
# 4                        tidak-diketahui
# ...                                  ...
# 996           narkotika-dan-psikotropika
# 997                            pencurian
# 998                           pembunuhan
# 999           narkotika-dan-psikotropika
# 1000          narkotika-dan-psikotropika
#
#                                                     url  ...  \
# 0     https://putusan3.mahkamahagung.go.id/direktori...  ...
# 1     https://putusan3.mahkamahagung.go.id/direktori...  ...
# 2     https://putusan3.mahkamahagung.go.id/direktori...  ...
# 3     https://putusan3.mahkamahagung.go.id/direktori...  ...
# 4     https://putusan3.mahkamahagung.go.id/direktori...  ...
# ...                                                 ...  ...
# 996   https://putusan3.mahkamahagung.go.id/direktori...  ...
# 997   https://putusan3.mahkamahagung.go.id/direktori...  ...
# 998   https://putusan3.mahkamahagung.go.id/direktori...  ...
# 999   https://putusan3.mahkamahagung.go.id/direktori...  ...
# 1000  https://putusan3.mahkamahagung.go.id/direktori...  ...
#
#                                               identitas  \
# 0     nama lengkap eny sulistiyaningsih binti mashad...
# 1     nama lengkap ali maftuhin bin nur salim tempat...
# 2     nama lengkap ir bambang sasongko bin r soewarn...
# 3     nama lengkap jk alias eklek tempat lahir klate...
# 4     nama lengkap oktavia cokrodiharjo bin poly cok...
# ...                                                 ...
# 996                                                 NaN
# 997   nama lengkap samsul arifin\ntempat lahir bangk...
# 998   nama lengkap saladin bin abd rahman tempat lah...
# 999   nama lengkap yayat supriatna bin omang alm tem...
# 1000  nama lengkap tempat lahir umur tanggal lahir j...
#
#                                       riwayat_penahanan  \
# 0     terdakwa ditahan dengan jenis tahanan rutan se...
# 1     terdakwa ditahan di rumah tahanan negara berda...
# 2                                terdakwa tidak ditahan
# 3     penyidik sejak tanggal 14 januari 2013 sampai ...
# 4                                terdakwa tidak ditahan
# ...                                                 ...
# 996                                                 NaN
# 997   terdakwa samsul arifin ditahan dalam dalam per...
# 998   terdakwa ditangkap pada tanggal 29 juni 2016\n...
# 999   1 penyidik sejak tanggal 11 maret 2017 sampai ...
# 1000                                                NaN
#
#                                         riwayat_perkara  \
# 0     pengadilan negeri tersebut\nsetelah membaca be...
# 1     pengadilan negeri tersebut\nsetelah membaca\np...
# 2     terdakwa didampingi oleh penasehat hukumnya ya...
# 3     terdakwa dalam perkara ini didampingi penaseha...
# 4     terdakwa dalam persidangan didampingi oleh pen...
# ...                                                 ...
# 996   telah mendengar keterangan para saksi dan terd...
# 997   pengadilan negeri tersebut\nsetelah membaca\np...
# 998   terdakwa didampingi oleh penasihat hukum 1 ahm...
# 999   terdakwa dalam perkara ini didampingi oleh pen...
# 1000  pengadilan negeri tersebut setelah membaca ber...
#
#                                        riwayat_tuntutan  \
# 0     setelah mendengar tuntutan requsitoir penuntut...
# 1     setelah mendengar surat tuntutan pidana requis...
# 2     telah mendengar pembacaan tuntutan pidana oleh...
# 3     setelah mendengar pembacaan tuntutan pidana da...
# 4     setelah mendengar pembacaan tuntutan pidana ya...
# ...                                                 ...
# 996   telah melihat dan meneliti barang bukti yang d...
# 997   setelah mendengar pembacaan tuntutan pidana ya...
# 998   setelah mendengar pembacaan tuntutan pidana ya...
# 999   setelah mendengar pembacaan tuntutan pidana ya...
# 1000                                                NaN
#
#                                         riwayat_dakwaan  \
# 0     menimbang bahwa terdakwa diajukan di persidang...
# 1     menimbang bahwa terdakwa didakwa oleh penuntut...
# 2     menimbang bahwa terdakwa diajukan di persidang...
# 3     menimbang bahwa terdakwa diajukan di persidang...
# 4     menimbang bahwa terdakwa diajukan ke persidang...
# ...                                                 ...
# 996   menimbang bahwa terdakwa diajukan oleh penuntu...
# 997   menimbang bahwa terdakwa diajukan ke persidang...
# 998   menimbang bahwa terdakwa diajukan ke persidang...
# 999   menimbang bahwa terdakwa diajukan ke persidang...
# 1000  menimbang bahwa terdakwa diajukan ke persidang...
#
#                                                   fakta  \
# 0     menimbang bahwa selanjutnya untuk membuktikan ...
# 1     menimbang bahwa untuk menguatkan dakwaan terse...
# 2     menimbang bahwa selanjutnya dipersidangan tela...
# 3     menimbang bahwa karena terdakwa menyangkal mel...
# 4     menimbang bahwa untuk membuktikan dakwaannya p...
# ...                                                 ...
# 996   menimbang bahwa di persidangan telah di dengar...
# 997   menimbang bahwa untuk membuktikan dakwaannya p...
# 998   menimbang bahwa untuk membuktikan dakwaannya p...
# 999   menimbang bahwa untuk membuktikan dakwaannya p...
# 1000  menimbang bahwa penuntut umum dipersidangan te...
#
#                                            amar_putusan  \
# 0     mengadili 1 menyatakan terdakwa eny sulistiyan...
# 1     mengadili 1 menyatakan terdakwa ali maftuhin b...
# 2     mengadili\n1 menyatakan terdakwa ir bambang sa...
# 3     mengadili\n1 menyatakan terdakwa jk alias ekle...
# 4     mengadili\n1 menyatakan terdakwa oktavia cokro...
# ...                                                 ...
# 996   mengadili\n1 menyatakan bahwa terdakwa wib wic...
# 997   mengadili\n1 menyatakan terdakwa syamsul arifi...
# 998   mengadili\n1 menyatakan terdakwa saladin bin a...
# 999   mengadili\n1 menyatakan terdakwa yayat supriat...
# 1000  mengadili\n1 menyatakan terdakwa fajar ali adn...
#
#                                                 penutup  \
# 0     demikian diputuskan dalam rapat permusyawarata...
# 1     demikianlah diputuskan dalam rapat permusyawar...
# 2     demikian diputuskan dalam rapat musyawarah maj...
# 3     demikianlah diputuskan dalam rapat permusyawar...
# 4     demikian diputuskan dalam sidang permusyawarat...
# ...                                                 ...
# 996   demikianlah diputuskan dalam rapat permusyawar...
# 997   demikianlah diputuskan pada hari kamis tanggal...
# 998   demikianlah diputuskan dalam rapat permusyawar...
# 999   demikianlah diputuskan dalam rapat permusyawar...
# 1000  demikianlah diputuskan dalam rapat permusyawar...
#
#                                             fakta_hukum  \
# 0                                                   NaN
# 1     menimbang bahwa berdasarkan keterangan saksi s...
# 2                                                   NaN
# 3     menimbang bahwa berdasarkan keterangan saksi s...
# 4     menimbang bahwa berdasarkan alat bukti dan bar...
# ...                                                 ...
# 996                                                 NaN
# 997   menimbang bahwa berdasarkan keterangan saksi s...
# 998   menimbang bahwa berdasarkan alat bukti yang be...
# 999   menimbang bahwa berdasarkan barang bukti yang ...
# 1000  menimbang bahwa berdasarkan alat bukti dan bar...
#
#                                      pertimbangan_hukum
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     menimbang selanjutnya bahwa majelis hakim akan...
# ...                                                 ...
# 996                                                 NaN
# 997   menimbang bahwa selanjutnya majelis hakim akan...
# 998   menimbang bahwa selanjutnya majelis hakim akan...
# 999   menimbang bahwa selanjutnya majelis hakim akan...
# 1000                                                NaN
#
# [1001 rows x 21 columns]

# %%
df_meta = df[['amar', 'amar_lainnya', 'id', 'klasifikasi', 'lama_hukuman',
       'lembaga_peradilan', 'provinsi', 'status', 'sub_klasifikasi', 'url']]

df_content = pd.DataFrame()
df_content['text'] = df[['kepala_putusan', 'identitas', 'riwayat_penahanan', 'riwayat_perkara',
       'riwayat_tuntutan', 'riwayat_dakwaan', 'fakta', 'amar_putusan',
       'penutup', 'fakta_hukum', 'pertimbangan_hukum']].agg(lambda x: '\n'.join(x.dropna()), axis=1)
  # Joins with \n as the separator

df_content
# Out:
#                                                    text
# 0     putusan\nno 45 pid b 2014 pn kds\ndemi keadila...
# 1     putusan\nnomor 157 pid b 2017 pn dm\ndemi kead...
# 2     putusan\nn o 03 pid s 2011 pn kdr\ndemi keadil...
# 3     putusan\nnomor 22 pid sus 2013 pn kl\ndemi kea...
# 4     putusan\nnomor 4 pid sus 2015 pn bl\ndemi kead...
# ...                                                 ...
# 996   putusan\nnomor 69 pid b 2011 pn yk\ndemi keadi...
# 997   putusan\nnomor 321 pid b 2018 pn bkl\ndemi kea...
# 998   putusan\nnomor 262 pid b 2016 pn bk\ndemi kead...
# 999   putusan\nnomor 479 pid sus 2017 pn bl\ndemi ke...
# 1000  putusan\nnomor 1428 pid b 2016 pn bdg\ndemi ke...
#
# [1001 rows x 1 columns]

# %% [markdown]
# # Preprocessing

# %%
def split_strings(row):
    return row.str.split('\n')

WORD_MIN_LENGTH = 2
def tokenize_text(text):
    words = word_tokenize(text)
    words = [word.lower() for word in words]
    words = [word for word in words if word not in STOP_WORDS and len(word) >= WORD_MIN_LENGTH]
    return words

def inverted_index(words):
    """Create a inverted index of words (tokens or terms) from a list of terms

    Parameters:
    words (list of str): tokenized document text

    Returns:
    Inverted index of document (dict)

   """
    inverted = {}
    for index, word in enumerate(words):
        locations = inverted.setdefault(word, [])
        locations.append(index)
    return inverted

def inverted_index_add(inverted, doc_id, doc_index):
    """Insert document id into Inverted Index

    Parameters:
    inverted (dict): Inverted Index
    doc_id (int): Id of document been added
    doc_index (dict): Inverted Index of a specific document.

    Returns:
    Inverted index of document (dict)

   """
    for word in doc_index.keys():
        locations = doc_index[word]
        indices = inverted.setdefault(word, {})
        indices[doc_id] = locations
    return inverted

# %%
# segment into sentences
df_content = df_content.apply(split_strings, axis=1)
df_content
# Out:
#                                                    text
# 0     [putusan, no 45 pid b 2014 pn kds, demi keadil...
# 1     [putusan, nomor 157 pid b 2017 pn dm, demi kea...
# 2     [putusan, n o 03 pid s 2011 pn kdr, demi keadi...
# 3     [putusan, nomor 22 pid sus 2013 pn kl, demi ke...
# 4     [putusan, nomor 4 pid sus 2015 pn bl, demi kea...
# ...                                                 ...
# 996   [putusan, nomor 69 pid b 2011 pn yk, demi kead...
# 997   [putusan, nomor 321 pid b 2018 pn bkl, demi ke...
# 998   [putusan, nomor 262 pid b 2016 pn bk, demi kea...
# 999   [putusan, nomor 479 pid sus 2017 pn bl, demi k...
# 1000  [putusan, nomor 1428 pid b 2016 pn bdg, demi k...
#
# [1001 rows x 1 columns]

# %%
# Build indexes
inverted_doc_indexes = {}
files_with_index = []
files_with_tokens = {}
doc_id=0

for i, row in tqdm(df_content.iterrows(), total=len(df_content)):
    for text in row['text']:
        #Clean and Tokenize text of each document
        words = tokenize_text(text)
        #Store tokens
        files_with_tokens[doc_id] = words

        doc_index = inverted_index(words)
        inverted_index_add(inverted_doc_indexes, doc_id, doc_index)
        files_with_index.append(f"doc-{i+1}")
        doc_id = doc_id+1
# Out:
# 100%|██████████| 1001/1001 [01:17<00:00, 12.84it/s]

# %%
count = 0
for key, value in inverted_doc_indexes.items():
    print(f"{key}: {value}")
    count += 1
    if count == 5:  # Print only the first 5 items
        break
# Out:
# putusan: {0: [0], 3: [12], 31: [9], 32: [11], 226: [8, 14], 321: [2], 326: [19], 340: [28], 344: [0], 347: [10], 487: [16], 490: [3], 725: [17], 727: [3, 15], 752: [22], 853: [21], 861: [29], 875: [0], 878: [13], 1772: [17], 1784: [17], 1789: [4], 1801: [27], 1804: [0], 1807: [12], 2030: [27], 2051: [2, 9, 11], 2121: [13], 2123: [0], 2126: [10], 2159: [11], 2381: [12], 2501: [5], 2504: [18], 2505: [4, 25, 40, 47], 2534: [0], 2537: [12], 2656: [29], 2730: [25], 2731: [23], 2733: [0], 2736: [10], 2873: [12], 2881: [4], 2891: [0], 2894: [15], 3093: [3, 11], 3096: [6], 3101: [22], 3208: [18], 3222: [19], 3224: [0], 3227: [10], 3553: [0], 3556: [12], 3570: [11], 3891: [25], 3928: [0], 3931: [10], 3959: [9], 3979: [12], 4003: [23], 4005: [0], 4008: [11], 4171: [23], 4191: [22], 4192: [16], 4194: [2], 4206: [0], 4209: [12], 4379: [0], 4383: [10], 4401: [7], 4569: [0], 4572: [13], 4689: [3, 13], 4701: [26], 4723: [11], 4774: [24], 4777: [20], 4783: [2], 4784: [14], 4788: [4], 4794: [5], 4796: [6], 4804: [1], 4810: [14], 4811: [0], 4815: [34], 4855: [4], 5317: [2], 5318: [0], 5319: [0], 5320: [0], 5398: [2, 9], 5481: [0], 5487: [10], 5745: [0], 
 16021: [13, 17], 16024: [13, 17], 16028: [13, 17], 16030: [13, 17], 16033: [13, 17], 16035: [13, 17], 16036: [13, 17], 16037: [1], 16038: [13, 17], 16039: [3], 16041: [13, 17], 16058: [12, 16], 16074: [12, 16], 16079: [4], 16090: [12, 16], 16095: [4], 16122: [12, 16], 16138: [12, 16], 16154: [12, 16], 16170: [12, 16], 16186: [12, 16], 16204: [11, 15], 16244: [6], 16344: [5, 40, 70], 16438: [15], 16439: [15], 16440: [15], 16441: [15], 16442: [15], 16443: [15], 16444: [15], 16445: [15], 16446: [15], 16447: [16], 16448: [8, 12], 16449: [8, 12], 16450: [8, 12], 16451: [8, 12], 16452: [8, 12], 16453: [8, 12], 16454: [8, 12], 16455: [8, 12], 16456: [8, 12], 16457: [8, 12], 16473: [9], 16500: [2], 16518: [11, 38, 44, 52], 16544: [18], 16550: [7, 11], 16551: [7, 11], 16552: [7, 11], 16553: [7, 11], 16554: [7, 11], 16555: [7, 11], 16556: [7, 11], 16557: [7, 11], 16558: [7, 11], 16559: [8, 12], 16563: [28], 16581: [8], 16868: [29], 16872: [2], 16878: [48], 16886: [35], 16898: [14], 16909: [14], 16921: [14], 16943: [2], 16947: [14], 16955: [14], 16961: [14], 16967: [14], 16995: [2], 17020: [5], 17304: [4], 17317:  ...

# %% [markdown]
# # TF-IDF

# %%
## number of documents each term occurs
DF = {}
for word in inverted_doc_indexes.keys():
    DF[word] = len([doc for doc in inverted_doc_indexes[word]])

total_vocab_size = len(DF)
print(total_vocab_size)
# Out:
# 55943

# %%
tf_idf = {} # Our data structure to store Tf-Idf weights

N = len(files_with_tokens)

for doc_id, tokens in tqdm(files_with_tokens.items()):

    counter = Counter(tokens)
    words_count = len(tokens)

    for token in np.unique(tokens):

        # Calculate Tf
        tf = counter[token] # Counter returns a tuple with each terms counts
        tf = 1+np.log(tf)

        # Calculate Idf
        if token in DF:
            df = DF[token]
        else:
            df = 0
        idf = np.log((N+1)/(df+1))

        # Calculate Tf-idf
        tf_idf[doc_id, token] = tf*idf
# Out:
# 100%|██████████| 250408/250408 [00:32<00:00, 7788.13it/s]

# %%
def ranked_search(k, tf_idf_index, file_names, query):
    """Run ranked query search using tf-idf model.

    Parameters:
    k (int): number of results to return
    tf_idf_index (dict): Data Structure storing Tf-Idf weights to each
                        pair of (term,doc_id)
    file_names (list): List with names of doc
    query (txt): Query text

    Returns:
    Top-k document that matchs the query.

   """
    tokens = tokenize_text(query)
    query_weights = {}
    for doc_id, token in tf_idf:
        if token in tokens:
            query_weights[doc_id] = query_weights.get(doc_id, 0) + tf_idf_index[doc_id, token]

    query_weights = sorted(query_weights.items(), key=lambda x: x[1], reverse=True)
    results = []
    print(query_weights[:k])
    for i in query_weights[:k]:
        results.append(file_names[i[0]])

    return results

# %%
print(ranked_search(4, tf_idf, files_with_index,
                    "yayat"))
# Out:
# [(250129, 16.971572935624938), (231638, 13.692558182749336), (231643, 13.692558182749336), (231772, 13.692558182749336)]
# ['doc-1000', 'doc-929', 'doc-929', 'doc-929']
